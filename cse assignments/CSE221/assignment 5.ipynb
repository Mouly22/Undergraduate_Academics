# %%
#1_a
inp1 = open('/Users/mouly/Downloads/input1a_2.txt', 'r')
out1 = open('/Users/mouly/Downloads/output1a_2.txt', 'w')
line1 = inp1.readline()
line1 = line1.split()
store = int(line1[0])
lst1 = [0]*(store+1)
lst2 = [0]*(store+1)

for x in range(len(lst2)):
    lst2[x] = lst1.copy()

for i in range(int(line1[1])):
    lines = inp1.readline()
    elem = lines.split()
    
    lst2[int(elem[0])][int(elem[1])] = int(elem[2])

val = ''
for p in lst2:
    for q in p:
    
        val += str(q)+' '
    val += '\n'
out1.write(val)


inp1.close()
out1.close()

# %%
# Adjascency List representation in Python
# Out:
# 0 :
#
# 1 : 4 3
#
# 2 :
#
# 3 : 2

# %%
#1_b perfect
inp2 = open('/Users/mouly/Downloads/input1b_1.txt', 'r')
out2 = open('/Users/mouly/Downloads/output1b_1.txt', 'w')
line1 = inp2.readline()
line1 = line1.split()
stor1 = int(line1[0])
stor2 = int(line1[1])

class Graph:
    def __init__(self, num, edge_num):
        self.V = int(num)
        self.E = int(edge_num)
        self.lst = []
        self.dct = {}
        for i in range(self.V+ 1):
            self.lst.append(i)        
    
    def edges_w_weight(self, strt, end, wght):
        for i in range(self.V + 1):
            self.lst.append(i)
            
        for vals in self.lst:
            if vals not in self.dct:
                self.dct[vals] = []         
        self.dct[strt].append(val)
        
    def g_print(self):
        for m, n in self.dct.items():
            print(str(m)+ ":", end ="")
            for elem in n:
                print((elem.vrtx, elem.wght), end=" ")
            print()  
        
graph = Graph(stor1, stor2)           
for i in range(int(line1[1])):
    lines = inp2.readline()
    elem = lines.split()
    graph.edges_w_weight(int(elem[0]), int(elem[1]), int(elem[2]))
graph.g_print()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-57-7d8eaa7c6ff9> in <module>
#      36     lines = inp2.readline()
#      37     elem = lines.split()
# ---> 38     graph.edges_w_weight(int(elem[0]), int(elem[1]), int(elem[2]))
#      39 graph.g_print()
#      40
#
# <ipython-input-57-7d8eaa7c6ff9> in edges_w_weight(self, strt, end, wght)
#      23             if vals not in self.dct:
#      24                 self.dct[vals] = []
# ---> 25         self.dct[strt].append(val)
#      26
#      27     def g_print(self):
#
# NameError: name 'val' is not defined

# %%
#task 2(BFS Traversal)
inp3 = open('/Users/mouly/Downloads/input2_1.txt', 'r')
out3 = open('/Users/mouly/Downloads/output2_1.txt', 'w')
line11 = inp3.readline()
line11 = line11.split()
stre1 = int(line11[0])
stre2 = int(line11[1])
class BFS_Traverse:
    def __init__(self, num, edges_num):
        self.vrtx = num
        self.edges = edges_num
        self.graph = {}
        
    def Edges_create(self, val1, val2):
        if val1 not in self.graph:
            self.graph[val1] = []
        if val2 not in self.graph:
            self.graph[val2] = []
        self.graph[val1].append(val2)
        
    def BFS(visited: list, graph: list, node: AdjNode, endPoint: AdjNode):
        import queue

        result = []
        q = queue.Queue()

        visited[node] = node
        q.put(node)

        while not q.empty():
            m = q.get()
            result.append(m)

            if m == endPoint:
                break

            node = graph[m]
            while node is not None:

                if visited[node.vertex] == None:
                    visited[node.vertex] = node.vertex
                    q.put(node.vertex)

                node = node.next

    return result
          
    
    def bfsTraversal(self, src) : 
        q = [] 
        visited = {} 
        q.append(src) 
        visited[src] = True 
        while (len(q)): 
            v = q.pop(0) 
            print(str(v) + " ");        
            for  ne in self.graph[v] :   
                if ne not in visited:
                    q.append(ne); 
                    visited[ne] = True
        
bfs = BFS_Traverse(stre1, stre2)           
for i in range(int(line11[1])):
    lines = inp3.readline()
    elm = lines.split()
    bfs.Edges_create(int(elm[0]), int(elm[1]))
    
for i in bfs.graph.keys():
    bfs.bfsTraversal(key)
    break
# Out:
# 1
# 3
# 4
# 2
# {1: [3, 4], 3: [2], 2: [], 4: []}

# %%
  # Traversal starting from src, BFS, Time O(V+E), Space O(V)
    def bfsTraversal(self, src) : 
        q = [] 
        visited = {} 
        q.append(src) 
        visited[src] = True 
        while (len(q) &gt; 0) : 
            v = q.pop(0) 
            print(str(v) + " ");        
            for  ne in self.adj[v] :   
                if ne not in visited:
                    q.append(ne); 
                    visited[ne] = True

# %%
inp3 = open('/Users/mouly/Downloads/input2_1.txt', 'r')
out3 = open('/Users/mouly/Downloads/output2_1.txt', 'w')
line1 = inp3.readline()
line1 = line1.split()
store1 = int(line1[0])
store2 = int(line1[1])

class Node:
    def __init__(self, val):
        self.vrtx = val
        self.next = None

def add_edge(self, source, destination):

        new_node = AdjNode(destination)
        index = source

        # If No graph connection present in the index
        # add the newNode as a new connection
        if self.graph[index] == None:
            self.graph[index] = new_node
            new_node = self.graph[index]

        else:
            # If Graph Connection Already Present
            # travarse them and add the newNode
            # after the last Node
            node = self.graph[index]
            while node.next is not None:
                node = node.next

            node.next = new_node
            new_node = node.next
class shortest_path:
    def __init__(self, v_num, edges_num):
        self.V = v_num
        self.E = edges_num
        self.arr = [None] * self.V

    def edges(self, val1, val2):
        n = Node(val2)
        n.next = self.arry[val1]
        self.arry[val1] = n
        
    def bfsTraversal(self, src) : 
        q = [] 
        visited = {} 
        q.append(src) 
        visited[src] = True 
        while (len(q)): 
            v = q.pop(0) 
            print(str(v) + " ");        
            for  ne in self.adj[v] :   
                if ne not in visited:
                    q.append(ne); 
                    visited[ne] = True

    def print_graph(self):
        val = ''
        for i in range(self.V):
            print(str(i) + " : ", end="")
            temp = self.arry[i]
            while temp:
                print(f"{temp.vrtx}", end=" ")
                temp = temp.next
            print(" \n")
            
graph = Graph(store1, store2)           
for i in range(int(line1[1])):
    lines = inp1.readline()
    elem = lines.split()
    graph.edges(int(elem[0]), int(elem[1]))

graph.print_graph()

# %%
inp3 = open('/Users/mouly/Downloads/input2_1.txt', 'r')
out3 = open('/Users/mouly/Downloads/output2_1.txt', 'w')
line1 = inp3.readline()
line1 = line1.split()
vrxt = int(line1[0])
edge_no = int(line1[1])

# %%
class AdjNode:
    def __init__(self, value) -> None:
        self.vertex = value
        self.next = None


class Graph:
    def __init__(self, total) -> None:
        self.length = total
        self.graph = [None] * self.length

    def add_edge(self, source, destination):

        new_node = AdjNode(destination)
        index = source

        # If No graph connection present in the index
        # add the newNode as a new connection
        if self.graph[index] == None:
            self.graph[index] = new_node
            new_node = self.graph[index]

        else:
            # If Graph Connection Already Present
            # travarse them and add the newNode
            # after the last Node
            node = self.graph[index]
            while node.next is not None:
                node = node.next

            node.next = new_node
            new_node = node.next

    def print_graph(self):

        graph = self.graph

        for i in range(1, self.length):
            if graph[i] is None:
                print(f"Vertex: {i}")
            else:
                print(f"Vertex: {i}", end=" -> ")

            node = graph[i]
            while node is not None:
                if node.next is None:
                    print(node.vertex, end="\n")
                    break

                print(node.vertex, end=" -> ")
                node = node.next


def BFS(visited: list, graph: list, node: AdjNode, endPoint: AdjNode):
    import queue

    result = []
    q = queue.Queue()

    visited[node] = node
    q.put(node)

    while not q.empty():
        m = q.get()
        result.append(m)

        if m == endPoint:
            break

        node = graph[m]
        while node is not None:

            if visited[node.vertex] == None:
                visited[node.vertex] = node.vertex
                q.put(node.vertex)

            node = node.next

    return result


def main():

    input_list = [i.replace("\n", "") for i in readLines("Input1.txt")]

    graph = Graph(int(input_list[0]) + 1)

    for i in range(1, len(input_list)):
        connections = [int(j) for j in input_list[i].split(" ")]
        for j in range(1, len(connections)):
            graph.add_edge(connections[0], connections[j])

    visited = [None] * (int(input_list[0]) + 1)
    result = BFS(visited, graph.graph, 1, 12)
    result = [str(i) for i in result]

    writeLines("Output2.txt", result)


if __name__ == "__main__":
    main()

# %%
#task 2(BFS Traversal)
inp3 = open('/Users/mouly/Downloads/input2_1.txt', 'r')
out3 = open('/Users/mouly/Downloads/output2_1.txt', 'w')
line1 = inp3.readline()
line1 = line1.split()
store1 = int(line1[0])
store2 = int(line1[1])

class shortest_path:
    def __init__(self, num, edges_num):
        self.vrtx = num
        self.edges = edges_num
        self.graph = {}
        
    def edges(self, val1, val2):
        if val1 not in self.graph:
            self.graph[val1] = []
        if val2 not in self.graph:
            self.graph[val2] = []
        self.graph[val1].append(val2)
        
    def g_print(self):
        for m, n in self.graph:
            print(f'{str(m)}:')
            for vals in n:
                print(vals)

        
ax = shortest_path(store1, store2)           
for i in range(store2):
    lines = inp3.readline()
    elm = lines.split()
    ax.edges(int(elm[0]), int(elm[1]))
ax.g_print()

# %%
#perfect 2
inp3 = open('/Users/mouly/Downloads/input2_1.txt', 'r')
out3 = open('/Users/mouly/Downloads/output2_1.txt', 'w')
line11 = inp3.readline()
line11 = line11.split()
stre1 = int(line11[0])
stre2 = int(line11[1])
class BFS:
    def __init__(self, num, edges_num):
        self.vrtx = num
        self.edges = edges_num
        self.graph = {}
        
    def Edges_create(self, val1, val2):
        if val1 not in self.graph:
            self.graph[val1] = []
        if val2 not in self.graph:
            self.graph[val2] = []
        self.graph[val1].append(val2)
           
    
    def BFS_TRAVS(self, start) : 
        storing = [] 
        checking_visit= {}
        storing.append(start)    
        checking_visit[start] = True 
        while len(storing): 
            temp = storing.pop(0) 
            val = ''
            val += str(temp)
            print(val)     
            for valus in self.graph[temp]:   
                if valus not in checking_visit:
                    storing.append(valus) 
                    checking_visit[valus] = True
        
bfs = BFS(stre1, stre2)           
for i in range(int(line11[1])):
    lines = inp3.readline()
    elm = lines.split()
    bfs.Edges_create(int(elm[0]), int(elm[1]))
    
for i in bfs.graph.keys():
    bfs.BFS_TRAVS(key)
    break
# Out:
# 1
# 3
# 4
# 2

# %%
#3 done 
inp4 = open('/Users/mouly/Downloads/input3_3.txt', 'r')
out4 = open('/Users/mouly/Downloads/output3_2.txt', 'w')
line = inp4.readline()
line = line.split()
vrtx1 = int(line[0])
edge1 = int(line[1])
class DFS:
    def __init__(self, num, edges_num):
        self.vrtx = num
        self.edges = edges_num
        self.dfsgraph = {}
        
    def Edge_create(self, val1, val2):
        if val1 not in self.dfsgraph:
            self.dfsgraph[val1] = []
        if val2 not in self.dfsgraph:
            self.dfsgraph[val2] = []
        self.dfsgraph[val1].append(val2)
        self.dfsgraph[val2].append(val1)
                
    def DFS_TRAVS(self, start):
        dfsdict = {}
        self.traverse(start, dfsdict)
        
    def traverse(self, val, dfsdict): 
        dfsdict[val] = True
        print(val)
        for p in self.dfsgraph[val]:
            if p not in dfsdict:
                self.traverse(p, dfsdict)
                
dfs = DFS(vrtx1, edge1)
for p in range(int(line[1])):
    lines = inp4.readline()
    elms = lines.split()
    dfs.Edge_create(int(elms[0]), int(elms[1]))
print(dfs.dfsgraph)
for j in dfs.dfsgraph.keys():
    dfs.DFS_TRAVS(j)
    break
# Out:
# {1: [2, 3, 4], 2: [1, 5], 3: [1, 9], 4: [1, 6, 7], 5: [2], 6: [4, 8], 7: [4], 8: [6], 9: [3]}
# 1
# 2
# 5
# 3
# 9
# 4
# 6
# 8
# 7

# %%
def DFS_TRAVS(self, start):
        pass
        
        
    def traverse(self, val):
        dfsdict = {}
        dfsdict[val] = 0


#     def dfsTraversal(self, src) : 

#         visited = {}
#         self.helper(src, visited)
        
#     def helper(self, v, visited) :
#         visited[v] = True
#         print(str(v))
#         for ne in self.adj[v] :
#             if ne not in visited:
#                 self.helper(ne, visited)

# %%
#perfect 2
inp3 = open('/Users/mouly/Downloads/input2_1.txt', 'r')
out3 = open('/Users/mouly/Downloads/output2_1.txt', 'w')
line11 = inp3.readline()
line11 = line11.split()
stre1 = int(line11[0])
stre2 = int(line11[1])
class BFS:
    def __init__(self, num, edges_num):
        self.vrtx = num
        self.edges = edges_num
        self.graph = {}
        
    def Edges_create(self, val1, val2):
        if val1 not in self.graph:
            self.graph[val1] = []
        if val2 not in self.graph:
            self.graph[val2] = []
        self.graph[val1].append(val2)
           
    
    def BFS_TRAVS(self, start) :
        
        storing = [] 
        checking_visit= {}
        storing.append(start)
        lst = []
        for m in checking_visit.values():
            m = 0
        checking_visit[start] = 1
        while len(storing): 
            temp = storing.pop(0)
            lst.append(temp)   
            for valus in self.graph[temp]:   
                if valus not in checking_visit:
                    storing.append(valus) 
                    checking_visit[valus] = 1
        printing = ''
        for v in lst:
            printing += str(v) + ' '
        out3.write(printing)
            
        
bfs = BFS(stre1, stre2)           
for i in range(int(line11[1])):
    lines = inp3.readline()
    elm = lines.split()
    bfs.Edges_create(int(elm[0]), int(elm[1]))
    
for i in bfs.graph.keys():
    bfs.BFS_TRAVS(i)
    break
out3.close()
